# %%
import sys 
sys.path.append('../')

import itertools
import numpy as np
from quantum_neural_networks import StateDiscriminativeQuantumNeuralNetworks as nnd

# %%
params = np.random.randn(11)
params_dict = nnd.decompose_parameters( params )
params_dict
# Out:
# {'n': 2,
#  'theta_u': [-0.05178560074317131],
#  'phi_u': [2.005130804320752],
#  'lambda_u': [-1.6746033444096287],
#  'theta_1': array([-1.029672]),
#  'theta_2': array([1.42386976]),
#  'theta_v1': array([0.36636233]),
#  'theta_v2': array([-2.69531274]),
#  'phi_v1': array([-0.56182717]),
#  'phi_v2': array([0.62553094]),
#  'lambda_v1': array([0.0466094]),
#  'lambda_v2': array([0.02256825])}

# %%
circuit = nnd.get_n_element_povm( params_dict['n'], 
                                            params_dict['theta_u'], params_dict['phi_u'], params_dict['lambda_u'], 
                                            params_dict['theta_1'], params_dict['theta_2'], 
                                            params_dict['theta_v1'], params_dict['theta_v2'], 
                                            params_dict['phi_v1'], params_dict['phi_v2'], 
                                            params_dict['lambda_v1'], params_dict['lambda_v2'] )

# %%
circuit.draw(output='mpl')

# %%
params = np.random.randn(19)
params_dict = nnd.decompose_parameters( params )
params_dict
# Out:
# {'n': 3,
#  'theta_u': [1.7713622935721125],
#  'phi_u': [0.29172958927040166],
#  'lambda_u': [0.7497375201690991],
#  'theta_1': array([-0.38573597,  0.52359053]),
#  'theta_2': array([ 0.51716259, -1.09924266]),
#  'theta_v1': array([-1.02239178,  0.35537838]),
#  'theta_v2': array([-0.10662874, -1.47070575]),
#  'phi_v1': array([0.59823988, 0.81896852]),
#  'phi_v2': array([0.44475952, 1.76783551]),
#  'lambda_v1': array([-0.1506715 , -0.14512439]),
#  'lambda_v2': array([-1.67754912,  1.73509709])}

# %%
circuit = nnd.get_n_element_povm( params_dict['n'], 
                                            params_dict['theta_u'], params_dict['phi_u'], params_dict['lambda_u'], 
                                            params_dict['theta_1'], params_dict['theta_2'], 
                                            params_dict['theta_v1'], params_dict['theta_v2'], 
                                            params_dict['phi_v1'], params_dict['phi_v2'], 
                                            params_dict['lambda_v1'], params_dict['lambda_v2'] )

# %%
circuit.draw(output='mpl')
